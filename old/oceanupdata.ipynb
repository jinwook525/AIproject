# %%
import schedule
import time
from datetime import datetime, timedelta
import mysql.connector
import requests
import os
from dotenv import load_dotenv

# .env 파일 로드
load_dotenv()

# 환경 변수에서 설정값 가져오기
DB_HOST = os.getenv("DB_HOST")
DB_PORT = int(os.getenv("DB_PORT", 3306))
DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_NAME = os.getenv("DB_NAME")
SERVICE_KEY = os.getenv("SERVICE_KEY")

# MySQL 연결 객체
def create_connection():
    """MySQL 연결을 생성하고 반환."""
    try:
        return mysql.connector.connect(
            host=DB_HOST,
            port=DB_PORT,
            user=DB_USER,
            password=DB_PASSWORD,
            database=DB_NAME,
            pool_name="mypool",
            pool_size=5
        )
    except mysql.connector.Error as e:
        log_error(f"Error connecting to MySQL: {e}")
        return None

conn = None

def ensure_connection():
    global conn
    if conn is None or not conn.is_connected():
        print("Database connection is not active. Attempting to reconnect...")
        conn = create_connection()
        if conn and conn.is_connected():
            print("Reconnected to the database.")
        else:
            print("Failed to reconnect to the database.")

# 에러 로깅
def log_error(message):
    with open("error_log.txt", "a") as log_file:
        log_file.write(f"{datetime.now()} - {message}\n")

# API에서 데이터 가져오기
def fetch_api_data():
    url = "http://marineweather.nmpnt.go.kr:8001/openWeatherNow.do"
    params = {
        "serviceKey": SERVICE_KEY,
        "resultType": "json",
        "mmaf": "101",
        "mmsi": "994401597",
        "dataType": "2"
    }

    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        log_error(f"Failed to fetch API data: {e}")
        return None

# 데이터 삽입 또는 업데이트
def upsert_data(data):
    try:
        ensure_connection()

        insert_query = """
        INSERT INTO oceandatatest (
            datetime, mmaf_code, mmaf_name, mmsi_code, mmsi_name, wind_direct, wind_speed,
            surface_curr_drc, surface_curr_speed, air_temperature, humidity, air_pressure,
            water_temperature, salinity, latitude, longitude
        )
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE
            wind_direct = VALUES(wind_direct),
            wind_speed = VALUES(wind_speed),
            surface_curr_drc = VALUES(surface_curr_drc),
            surface_curr_speed = VALUES(surface_curr_speed),
            air_temperature = VALUES(air_temperature),
            humidity = VALUES(humidity),
            air_pressure = VALUES(air_pressure),
            water_temperature = VALUES(water_temperature),
            salinity = VALUES(salinity);
        """

        with conn.cursor() as cursor:
            if "result" in data and "recordset" in data["result"]:
                for entry in data["result"]["recordset"]:

                    cursor.execute(insert_query, (
                        datetime.strptime(entry["DATETIME"], "%Y%m%d%H%M%S"),
                        entry["MMAF_CODE"],
                        entry["MMAF_NM"],
                        entry["MMSI_CODE"],
                        entry["MMSI_NM"],
                        float(entry["WIND_DIRECT"]) if entry["WIND_DIRECT"] != "미제공" else None,
                        float(entry["WIND_SPEED"]) if entry["WIND_SPEED"] != "미제공" else None,
                        float(entry["SURFACE_CURR_DRC"]) if entry["SURFACE_CURR_DRC"] != "미제공" else None,
                        float(entry["SURFACE_CURR_SPEED"]) if entry["SURFACE_CURR_SPEED"] != "미제공" else None,
                        float(entry["AIR_TEMPERATURE"]) if entry["AIR_TEMPERATURE"] != "미제공" else None,
                        float(entry["HUMIDITY"]) if entry["HUMIDITY"] != "미제공" else None,
                        float(entry["AIR_PRESSURE"]) if entry["AIR_PRESSURE"] != "미제공" else None,
                        float(entry["WATER_TEMPER"]) if entry["WATER_TEMPER"] != "미제공" else None,
                        float(entry["SALINITY"]) if entry["SALINITY"] != "미제공" else None,
                        round(float(entry["LATITUDE"]), 5),
                        round(float(entry["LONGITUDE"]), 5)
                    ))
                conn.commit()
        print("Data successfully inserted or updated.")
    except mysql.connector.Error as e:
        log_error(f"MySQL error: {e}")
    except Exception as e:
        log_error(f"Unexpected error: {e}")

# 작업 스케줄링
def register_task():
    if not any(job.job_func == scheduled_task for job in schedule.jobs):
        schedule.every(10).minutes.do(scheduled_task)
        print("Task registered successfully.")
    else:
        print("Task already registered.")

def scheduled_task():
    print(f"Running scheduled task at {datetime.now()}")
    api_data = fetch_api_data()
    if api_data:
        upsert_data(api_data)

# 실행
if __name__ == "__main__":
    ensure_connection()

    print("Fetching initial data...")
    api_data = fetch_api_data()
    if api_data:
        upsert_data(api_data)

    register_task()

    print("Scheduler is running... Press Ctrl+C to stop.")
    try:
        while True:
            schedule.run_pending()
            time.sleep(1)
    except KeyboardInterrupt:
        print("Scheduler stopped. Closing database connection...")
        if conn and conn.is_connected():
            conn.close()
            print("Database connection closed.")
# Out:
# Database connection is not active. Attempting to reconnect...
# Reconnected to the database.
# Fetching initial data...
# Data successfully inserted or updated.
# Task registered successfully.
# Scheduler is running... Press Ctrl+C to stop.
# Running scheduled task at 2025-01-20 13:33:44.273015
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 13:43:44.698851
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 13:53:45.132946
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:03:45.554066
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:13:46.115126
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:23:46.536909
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:33:47.137230
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:43:47.564834
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 14:53:47.929360
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:03:48.291943
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:13:48.685351
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:23:49.261174
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:33:49.618296
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:43:50.138727
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 15:53:50.546674
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:03:50.923278
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:13:51.278359
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:23:51.768430
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:33:52.138303
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:43:52.533968
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 16:53:52.926487
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:03:53.340734
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:13:53.723124
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:23:54.107011
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:33:54.467293
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:43:54.846695
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 17:53:55.208086
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 18:03:55.607471
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 18:13:55.995822
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 18:23:56.354702
# Running scheduled task at 2025-01-20 18:33:56.706900
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 18:43:57.145093
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 18:53:57.518855
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 19:03:57.912155
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 19:13:58.266209
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 19:24:00.191627
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 19:34:01.362263
# Running scheduled task at 2025-01-20 19:44:01.732934
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 19:54:02.127620
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:04:02.700132
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:14:03.843628
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:24:04.194760
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:34:04.548712
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:44:04.888261
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 20:54:05.271189
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:04:05.722224
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:14:06.107659
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:24:06.485590
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:34:06.850919
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:44:07.255469
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 21:54:07.625603
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:04:07.982091
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:14:08.353275
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:24:09.503699
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:34:09.860952
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:44:10.290072
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 22:54:10.701405
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:04:11.110006
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:14:11.455347
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:24:11.836051
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:34:12.227792
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:44:12.636571
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-20 23:54:13.016742
# Running scheduled task at 2025-01-21 00:04:13.398405
# Running scheduled task at 2025-01-21 00:14:13.743949
# Running scheduled task at 2025-01-21 00:24:14.106239
# Running scheduled task at 2025-01-21 00:34:14.473877
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 00:44:14.864376
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 00:54:15.230713
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:04:15.596737
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:14:15.954385
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:24:16.372654
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:34:16.709729
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:44:17.129374
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 01:54:17.478783
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:04:17.865681
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:14:18.218325
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:24:18.549473
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:34:18.906226
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:44:19.362655
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 02:54:19.709100
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:04:20.098939
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:14:20.463418
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:24:21.058983
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:34:21.423843
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:44:21.807394
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 03:54:22.137041
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:04:22.503317
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:14:22.825885
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:24:23.233894
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:34:23.600528
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:44:26.212822
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 04:54:26.853422
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:04:27.204167
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:14:27.539040
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:24:27.916655
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:34:28.260136
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:44:28.672762
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 05:54:29.084207
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:04:29.490900
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:14:29.834114
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:24:30.236290
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:34:30.592245
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:44:31.008154
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 06:54:31.374481
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:04:31.744767
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:14:32.069395
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:24:32.719082
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:34:33.097620
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:44:33.534838
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 07:54:33.917193
# Running scheduled task at 2025-01-21 08:04:34.303128
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 08:14:34.687586
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 08:24:35.084841
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 08:34:35.487596
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 08:44:35.857496
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 08:54:36.262731
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:04:36.614730
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:14:36.969766
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:24:37.340010
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:34:37.728556
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:44:38.168857
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 09:54:38.607187
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:04:39.072645
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:14:39.545120
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:24:39.959464
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:34:40.316399
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:44:40.712155
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 10:54:41.223630
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:04:41.630419
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:14:41.975596
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:24:42.383946
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:34:42.830648
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:44:43.206747
# Data successfully inserted or updated.
# Running scheduled task at 2025-01-21 11:54:45.227777
# Data successfully inserted or updated.
# Scheduler stopped. Closing database connection...
# Database connection closed.

# %%
import schedule

# %%
print(schedule.jobs)
# Out:
# []
